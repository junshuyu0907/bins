# %% [markdown]
# <a href="https://colab.research.google.com/github/junshuyu0907/bins/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 修复 numpy
import numpy as np
np.int = int
np.float = float

# 安装 t3f
# !pip install git+https://github.com/Bihaqo/t3f.git
# Out:
# ...
#   Cloning https://github.com/Bihaqo/t3f.git to /tmp/pip-req-build-j92jn75y
#   Running command git clone --filter=blob:none --quiet https://github.com/Bihaqo/t3f.git /tmp/pip-req-build-j92jn75y
#   Resolved https://github.com/Bihaqo/t3f.git to commit 8096b3883867087206f44e32a99d8ab19255dc25
#   Preparing metadata (setup.py) ... done
# ...

# %%
# =========================
# 1. 导入库
# =========================
import tensorflow as tf
import numpy as np
import t3f

from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import optimizers

# 固定随机种子
tf.random.set_seed(0)
np.random.seed(0)

# =========================
# 2. 加载数据
# =========================
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# 归一化
x_train = x_train / 127.5 - 1.0
x_test = x_test / 127.5 - 1.0

# One-hot 编码
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# =========================
# 3. 构建 Tensor Train 模型
# =========================
model = Sequential()

# 展平输入
model.add(Flatten(input_shape=(28, 28)))

# TT 层（核心！压缩层）
tt_layer = t3f.nn.KerasDense(
    input_dims=[7, 4, 7, 4],   # 28*28=784 → 分解结构
    output_dims=[5, 5, 5, 5],  # 625
    tt_rank=4,
    activation='relu'
)

model.add(tt_layer)

# 输出层
model.add(Dense(10))
model.add(Activation('softmax'))

# =========================
# 4. 编译模型
# =========================
optimizer = optimizers.Adam(learning_rate=1e-2)

model.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# 打印模型结构
model.summary()

# =========================
# 5. 训练模型
# =========================
model.fit(
    x_train,
    y_train,
    epochs=3,
    batch_size=64,
    validation_data=(x_test, y_test)
)

# =========================
# 6. 测试模型
# =========================
loss, acc = model.evaluate(x_test, y_test)
print("测试准确率:", acc)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ tt_dense_1 (KerasDense)         │ (None, 625)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │         6,260 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 10)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,260 (24.45 KB)
#  Trainable params: 6,260 (24.45 KB)
# ...
